# %% [markdown]
# # Subject 2 - Baseline
# Preprocessing and save to clean data file

# %%
import mne
import matplotlib.pyplot as plt 
import numpy as np
import antropy  

raw = mne.io.read_raw_eeglab('../data_raw/ds006437/sub-002/ses-0/eeg/sub-002_ses-0_task-baseline0_eeg.set', preload=True)
# Out:
# Reading c:\Users\User\Documents\eeg-hypnosis-complexity\notebooks\..\data_raw\ds006437\sub-002\ses-0\eeg\sub-002_ses-0_task-baseline0_eeg.fdt
# Reading 0 ... 96032  =      0.000 ...   375.125 secs...

# %%
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage)

raw.filter(1.5, 30.0, fir_design='firwin')
raw.plot()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1.5 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.50
# - Lower transition bandwidth: 1.50 Hz (-6 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 565 samples (2.207 s)
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.info['bads'] = ['Fp1', 'AF7', 'AF3', 'T7', 'TP7', 'CP5', 'F3', 'F5', 'F1', 'FC3']
raw.interpolate_bads(reset_bads=True)
# Out:
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 96.3 mm
# Computing interpolation matrix from 54 sensor positions
# Interpolating 10 sensors
# <RawEEGLAB | sub-002_ses-0_task-baseline0_eeg.fdt, 64 x 96033 (375.1 s), ~47.0 MiB, data loaded>

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.save('C:/Users/User/Documents/eeg-hypnosis-complexity/data_clean/sub-002/ses_0/sub-002_ses-0_raw.fif', overwrite=True)
# Out:
# Writing C:\Users\User\Documents\eeg-hypnosis-complexity\data_clean\sub-002\ses_0\sub-002_ses-0_raw.fif
# Closing C:\Users\User\Documents\eeg-hypnosis-complexity\data_clean\sub-002\ses_0\sub-002_ses-0_raw.fif
# [done]
# [WindowsPath('C:/Users/User/Documents/eeg-hypnosis-complexity/data_clean/sub-002/ses_0/sub-002_ses-0_raw.fif')]
